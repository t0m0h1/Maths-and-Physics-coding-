# %% [markdown]
# ### Python coding challenges focused on basic maths and physics concepts

# %% [markdown]
# #### Area and perimeter of a circle

# %%
import math

# Area=πr2

pi = math.pi

# Area
def area(radius):
    val = pi * radius * radius
    return round(val, 2)

print(area(6))
# Out:
# 113.1

# %% [markdown]
# ### Distance between two points (Euclidean Distance)
# - Write a function that calculates the distance between two points
# - This is the same as drawing a line between point A and point B

# %%
import numpy as np

point1 = np.array([1, 2, 3])
point2 = np.array([4, 6, 8])

def distance(p1, p2):
    return np.linalg.norm(p1 - p2)

dist = distance(point1, point2)
print("Euclidean Distance:", dist)
# Out:
# Euclidean Distance: 7.0710678118654755

# %% [markdown]
# ### Create 3D visualisation of Euclidean Distance

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Points
point1 = np.array([1, 2, 3])
point2 = np.array([4, 6, 8])

# Function to calculate distance
def distance(p1, p2):
    return np.linalg.norm(p1 - p2)

# Calculate distance
dist = distance(point1, point2)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(*point1, color='red', label='Point 1 (1, 2, 3)')
ax.scatter(*point2, color='blue', label='Point 2 (4, 6, 8)')

ax.plot([point1[0], point2[0]],
        [point1[1], point2[1]],
        [point1[2], point2[2]], color='green', label=f'Distance: {dist:.2f}')

# Set labels
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')

ax.legend()
plt.show()

# %% [markdown]
# ### Kinetic Energy
# - Program to find the kinetic energy (Joules) of an object with mass M and velocity V:
#
#
# $$
# KE = \frac{1}{2} mv^2
# $$

# %%
M = 0
V = 0

# consider mass to be KG and velocity to be m/s

def get_KE(M, V):
    KE = 0.5 * M * V**2
    return KE

if __name__ == '__main__':
    print(get_KE(1, 2), ' Joules')
# Out:
# 2.0  Joules
